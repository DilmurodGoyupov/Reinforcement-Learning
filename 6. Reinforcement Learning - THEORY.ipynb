# %% [markdown]
# # <center> <h1>   🎮  🧑‍💻  🕹

# %% [markdown]
# # <center> Reinforcement Learning (RL - Mustahkamlab o’rgatish) - bu agentga ma’lum bir raqamli mukofotni maksimal darajada oshirish yoki jazo funksiyasini kamaytirish maqsadida ma’lum bir muhitda harakatlar ketma-ketligini bajarishga imkon beradigan algoritmlar va usullarni o’rganish bilan shug’ullanadigan, mashinali o’rgatishning bir bo’limi hisoblanadi. Klassik o’rgatish usullaridan farqli o’laroq, agentning datasetida to’g’ri javoblar yo’q, u atrof-muhit bilan o’zaro aloqada bo’lgan tajribasidan bilim olishi kerak. Ya’ni biz o’yin o’ynashni o’rgatayotgan bo’lsak bizda tog’ri javoblar yo’q, bizda maqsad bor ya’ni o’yinni keyingi bosqichiga o’tish, agent harakatlanadi va qaysidur joyda halokt bo’ladi, u bunga jarima oladi va buni eslab qolishga harakat qiladi va keyingi safar o’sha yerda masalan sakrab o’tishga harakat qiladi, ya’ni shu yerda halokt bo’lmaslikka harakat qiladi.
#
#
# ## <center> <a href="https://docs.google.com/document/d/1HpDYGvreqOWx2rf1CDUrsZAl7imA1RaZ/edit?usp=sharing&ouid=102171666806846134877&rtpof=true&sd=true">Word versiyasini ko'rish uchun shu yerga bosing</a>

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-02-13 114905.png](attachment:f47a172d-efe4-48f9-8251-7637f5815b97.png)

# %% [markdown]
# # Reinforcement Learning(Mustahkamlab o’rgatish) muammolarini hal qilishning ikkita asosiy yondashuvi mavjud bular `Modelsiz` va `Modelga asoslangan` yondashuv.
#
# •	Modelsiz RL(Model-Free RL):
# - Bu agentni muhitning aniq modelini yaratmasdan turib, muhitda qaror qabul qilishni o’rganishidir,
# - Modelsiz RL-da agent shu muhit bilan ta’sirdan olgan tajribasi asosida atrof-muhit bilan o’zaro aloqada bo’ladi,
# - Eng mashhur Model-Free RL algoritmlariga Q-learning, SARSA va chuqur o’rgatishga asoslangan Deep Q-Networks (DQN), Policy Gradient Methods va boshqalar kiradi.
#
# •	Modelga asoslangan RL(Model-Based RL):
# - Bu agentning harakatlariga javoban atrof-muhit holati qanday o’zgarishini bashorat qilish uchun atrof-muhit modelini quradigan yoki ishlatadigan agentlarni tayyorlashga yondashuv.
# - Modelga asoslangan RLda agent o’z harakatlarini rejalashtirish va qarorlar qabul qilish uchun ushbu modeldan foydalanadi.
# - Modelga asoslangan RL ning afzalliklari ma’lumotlardan samaraliroq foydalanish va simulyatsiyalardan o’rganish qobiliyatini o’z ichiga oladi, bu haqiqiy muhit bilan o’zaro aloqa qilish qimmat yoki xavfli bo’lgan hollarda foydali bo’lishi mumkin.
# - Biroq, atrof-muhitning aniq modelini yaratish ba’zi hollarda qiyin bo’lishi mumkin va to’liq bo’lmagan yoki noto’g’ri modelga asoslangan rejalashtirish yomon qaror chiqarishga olib kelishi mumkin.
#
# `Modelsiz RL(Model-Free RL)` odatda atrof-muhit modelini yaratish qiyin yoki imkonsiz bo’lgan hollarda yoki agent atrof-muhit bilan o’zaro ta’sirlardan bevosita o’rganishi kerak bo’lgan hollarda qo’llaniladi. Masalan Super Mario o’yinin real modelini yarata olmaymiz shuning uchun ham uning tayor modellar(algoritmlar) orqali o’rgatishimiz mumkin. Masalan biz Super Marioni o’yinini PPO(Proximal Policy Optimization) orqali o’rgatishimiz mumkin.

# %% [markdown]
# <center>
#
# # ![560ebbe7dd0895325c8b458e.jpg](attachment:72b67ba6-1efa-4bc0-af4c-c1f277fc7843.jpg)
#
# #### `Modelga asoslangan RL(Model-Based RL)` atrof-muhitning aniq modeli mavjud bo’lganda yoki agentning xatti-harakatlarini samarali rejalashtirish kerak bo’lganda ishlatiladi. Biz haqiqiy robotning aniq modelini yaratamiz va uni o’rgatamiz. Real hayotda uni ko’plab epoch o’qitish qiyin va qimmat bo’lishi mumkin. Lekin biz robotning aniq modelini yaratsak va uni kompyuterda o’rgatsak bu ishni osonlashtiradi va tezlashtiradi. Shuni esdan chiqarmaslik kerakki biz modelni aniq qilib yaratishimiz kerak aks holda u keyinchalik robotning yomon ishlashiga olib kelishi mumkin.

# %% [markdown]
# <center>
#
# # ![a6b56784b1967612199b1340c3e35780d01df943.jpeg](attachment:44d08e64-8c52-40af-b8c9-a534afbfbd92.jpeg)
#
# ### O’zi aslida 1-rasmimizdagi Model-Free RL 2 ga emas 3 ga bo’linadi desak ham bo’ladi. Pastdagi rasmlarga qarang

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-02-13 114905 — копия.png](attachment:a75014cb-6fc1-4830-bdb5-a8c110337dfc.png)

# %% [markdown]
# <center>
#
# # ![image2.png](attachment:431c2c63-1eda-4576-b94f-68041577712b.png)
#
# #### Policy-Based bu `Policy Optimization`, Value-Based bu `Q-learning`, Ikkalasining keshimasi yoki ikkla metodlarni ham o’zga ichiga olishi bu `Actor-Critic` metodi deyiladi.
# #### Keling ularning har biriga alohida to’xtalib o’tamiz.

# %% [markdown]
# # <center> Q-Learning
#
# #### <center> Keling avvalam bor biz bir nechta kerak bo’lgan parameter bilan tanishib olamiz.

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 150528.png](attachment:7a55d79a-fa7a-4d3a-809d-ced0123bb8aa.png)

# %% [markdown]
# # Reward ham har xil bo’lishi mumkin. Masalan biz super mario o’ynapmiz va bizning vazifamiz iloji boricha tezroq finishga borish. Finishga borish vaqtida biz halokt bo’lmasak va har xil to’siqlarni sakrab o’tsak reward olamiz. Masalan shaxmat o’ynaganimizda biz faqat o’yin oxirida yutgan yoki yutmaganligimizni bilamiz. Chunki o’yinning asl mohiyati raqibni yutish va biz bunday holatlarda, masalan filni yeganiga reward berishimiz va aksincha bizning piyodamizni yeyishgani uchun reward ishlatishimiz mumkin. Lekin biz raqibning piyodasini yeb qo’yganimiz umumiy o’yinga qanday ta’sir qilishini oldindan bilmaymiz. Rewardnining o’zini ham modellashtirish qiyin jarayon hisoblanadi.
#
# #### Traektoriya-{s0 a0, s0, a1,  ….}   bu bizning epizodimizdagi(epizod bizda bu bir nechta harakatlar va statelar to’plami) harakatlar trayektoriyasi. s0, holatda a0 harkatni bajardik, keyin s1 holatda a1 harkatni bajardik va hakazo..
#
# #### Umumiy discounted(chegirma - дисконтированный) reward γ, γϵ[0,1]
#
# #### Demak biz qandaydur t vaqt oralig’idamiz. Quyidagicha qilib rewardni hisoblaymiz:

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 150655.png](attachment:6571c298-298c-4d68-952e-172b2b66f3d5.png)
#
# #### Bizda shu holatdagi R unchalik to’g’ri emas. Masalan biz bu yerda uncha ko’p bo’lmagan reward oldik, lekin keyingi qadamda biz aniq o’yinni yutamiz. Bunday holatda biz kelajakni(keyingi qadamni) hisobga olishimiz kerak. Ya’ni R(t+1)+ R(t+2)+⋯   holat uchun ham rewardni hisoblashimiz kerak. (Biz rewardni aniq bir episode tugagandan keyin hisoblaymiz. Rewardimizning summasi iloji boricha maksimum bo’lishi kerak) Bu quyidagicha bo’ladi:

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 151231.png](attachment:816aea2c-2622-41e0-8b97-5ef41c0a77dc.png)
#
# #### Bizda R(t+1) dagi reward hozirgi holat uchun sal ahamiyati pastroq. Chunki bizga hozirgi reward muhimroq. Bundan xulosa qilishimiz mumkinki har safar bizda reward R(t+1)bizga kamroq weight bilan keladi.(Nega kamroq weight bilan keladi chunki γ  darajaga ko’tarilgan sari kichik son bo’lib boradi va tabiiyki keyingi qiymatga ko’payytirilganda kichik son chiqadi.)
# #### Bizning asosiy vazifamiz

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 151354.png](attachment:0ce777c3-7efa-4a31-b6ce-10a0f3209f8a.png)
#
# #### qiymatni olish. Ya’ni maxsimum reward olish. Bu biz tog’ri o’ynayotganimizni bildiradi. R(t+1)rewardni baholash uchun bizga yana bitta funskiya kerak bo’ladi.
# ### Foydali harakat funksiyasi -  kelajakdagi mukofotni(rewardni) bashorat qilish va holatlarni(state) baholash uchun ishlatiladi.

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 151510.png](attachment:016f457b-8da8-4e1a-bba2-b3e6413ec8d6.png)
#
# #### bu bizning Rt ning hozirgi vaqtda s holat(state) uchun matematik kutilmasi. Biz demak mukofotni bashoratini(ehtimolligini) hisoblaymiz. Biz buni hozirgi holatimizni(stateni) baholash uchun ishlatamiz.  Reward bizning politikamiz/strategiyamizga bog’liq.  Agar biz shaxmat o’ynayotgan bo’lsak va  g’alabaga bir qadam qolgan bolsak, qandaydur yangi o’yinchi buni bilmasligi mumkin, ya’ni o’yinchi shaxmat o’ynashni bilmasligi mumkin, u keyingi qadamda yutishi mumkin bo’lgan  holatda bo’ladi lekin buni qilmaydi. Bu shuni anglatadiki bizning matematik kutilmamizni politika orqali baholash kerak. Bu yerda ham shu narsa ko’rsatilgan π politika/strategiya orqali matematik kutilma hisoblanyapti. Eng yaxshi kutilma maxsimum qiymatda bo’ladi.

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 151941.png](attachment:df160062-ad84-4218-b7c3-62394c9fc20d.png)
#
# #### Demak biz π politika orqali

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 152015.png](attachment:166e78c4-ef57-48b8-8f1e-62a15f9ea1b3.png)
#
# #### s holatda, a harakatni tanlaymiz va u

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 152053.png](attachment:1eba32cf-f95a-4314-9413-f7a3ae1cbf12.png)
#
# #### Oddiyroq aytadigan bo’lsak biz shunday politikani tanlashimiz kerakkmi u bizga max V*(s) ni berishi kerak

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 151941.png](attachment:e8b0eb8f-8233-4bbc-a721-d0c604589987.png)
#
# #### Formulani quidagicha yozishimiz ham mumkin.

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 152217.png](attachment:980b3666-80bf-4e82-b9d3-96acdfbf2b42.png)
#
# #### r(st, at) bu hozirgi holatdagi rewardimiz, γr(s(t+1),a(t+1) )+ γ^2 r(s(t+2),a(t+2) ) bular esa keyingi holatlardage rewardimizning matematik kutilmasi. Oddiyroq aytadigan bo’lsak hozirgi holatimizning rewardiga, hozirgi holatda turgan holda, keyingi holatlarni rewardini qo’shamiz. Yanada sodaroq qilib aytadigan bo’lsak, masalan biz hozir bankdan 100 ming olishimiz kerak va 1 yildan so’ng esa 120 ming o’lishimi kerak. Bizga hozirgi 100 mingimiz va 1 yildan keyingi 120 ming ham muhim.
# #### Aslida tepadgi formulamiz Bellman tenglamasi hisoblanadi. Bizning yakuniy formula quyidagicha bo’ladi.

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 155930.png](attachment:c5943b45-6370-46f7-a4e1-afd05ca64002.png)
#
# #### Keling bizda quyidagicha matritsa bo’lsin. Biz bu matritsada o’nga, chapga, pastga, tepaga yurishimiz mumkin.
# #### Biz 0, -1, 1 olishimiz mumkin, x biz bu yerga yura olmaymiz degani. Demak holatimizni tepadagi formula bilan hisoblab ko’ramiz.

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-02-10 155849.png](attachment:b8c12749-3bec-4cf0-9a66-c6dfb90e0b10.png)

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 160228.png](attachment:5fc4e32f-b0d1-4374-b58f-5d0a7d4a7d83.png)

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-02-10 161038.png](attachment:fb479af4-572e-4b56-ac71-d32d22bf6722.png)

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 160326.png](attachment:b59487cd-c9f0-492d-a5ba-e2e1c29b424c.png)

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-02-10 164456.png](attachment:b0a99f21-8cb7-4457-8c5f-621f0f26c3b8.png)

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 160502.png](attachment:6460f54f-80fc-44fa-b697-b9bf4a5da95e.png)

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-02-10 164812.png](attachment:33b52a1e-cd44-4d6e-b1ed-ba23f009faf7.png)

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 160545.png](attachment:3084b7eb-b155-4cc6-aa18-456d02f6f6e5.png)

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-02-10 165628.png](attachment:05a2ea6a-339b-4b24-80e8-c3b9bd0d1b0f.png)

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 160652.png](attachment:6f24e81c-95b2-4625-b856-6a18160c64c8.png)

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-02-10 170146.png](attachment:8e2bb0a6-0304-4cb7-8130-af18f0587f69.png)

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 160725.png](attachment:77ec44df-ae05-4e6f-8c5a-094d6e5cd440.png)

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-02-10 172003.png](attachment:1e4031ff-35fd-4658-ad95-f7726c4a2534.png)
#
# #### Demak biz shu orqali harakat qilsak V bizda maksumum bo’ladi.
# #### Bu usul unchalik yaxshi emas chunki biz olayotgan strategiyalar determinantlashgan, ya’ni biz aniq qanday harakatni amalga oshirishimizni bilamiz. Bu hamma hollarda ham yaxshi emas.
# #### Yana ham soddaroq tushuntiradigan bo’lsak bizda start va finish bor.

# %% [markdown]
# <center>
#
# # ![1 wjP3fAakxNpUEfrj1-hqKw.jpg](attachment:7a7309f5-35df-4b4d-bdaa-e90209f3307f.jpg)
#
# #### Harakatlarimiz quyidagicha

# %% [markdown]
# <center>
#
# # ![1 qXZBHXwUQMa55ajabukyPw.jpg](attachment:32f4c95a-b389-46f5-b392-8103d948f310.jpg)
#
# #### Agar biz har bir qadam uchun -1 reward oladi deb hisoblasak

# %% [markdown]
# <center>
#
# # ![1 WvoR2I4q2Hzq3YM__I9ziA.jpg](attachment:abca4d58-36b3-4612-bab6-c73a7df7e56a.jpg)
#
# #### Oddiyroq aytadigan bo’lsak V ni bilishimiz orqali biz politikamiz/strategiyamizni ham bilib olamiz. Biz demak max V bizga bergan harakatlarni bilamiz va shu orqali o’yinni startdan boshlab qayerdan yurib yutishimizni ham bilib olamiz.

# %% [markdown]
# <center>
#
# # ![1 WvoR2I4q2Hzq3YM__I9ziA — копия.jpg](attachment:05b74a58-9480-4478-a83d-430f3a4615c0.jpg)
#
# #### Lekin biz uchun V(Foydali harakat funksiyasi) kamlik qiladi.
#
# #### Bizda yana bitta Foydali harakat funksiyasi bor. Bu  Q funksiya. Oldingi V funkiyamiz bu holat foydaliligini baholash uchun kerak edi, bunisi esa harakatni foydaliligini baholash uchun kerak.
# #### Q(a,s)-  π strategiyani bajarish davomidan s holatda tanlangan a harakatni bajarish davomida olingan matematik kutilma.

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 161224.png](attachment:2c7a411b-77cd-4906-a389-26665178d77d.png)
#
# #### Bu bizing R_t ning hozirgi vaqtda s holat(state) va a harakat(action) uchun matematik kutilmasi. Tepadagi funksiya singari bu funskiyada ham eng yaxshi kutilma maxsimum qiymatda bo’ladi:

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 161313.png](attachment:b0299e0f-8dbd-44d8-9f6f-0b0f82f69474.png)
#
# #### Oddiyroq aytadigan bo’lsak biz shunday politikani tanlashimiz kerakkmi u bizga max Q^* (s,a)ni berishi kerak.
# #### Yanada oddiyroq aytadigan bo’lsak argmaxQ^π (s,a) demak biz s holatdamiz va bizda  masalan 10 ta qilishimiz mumkin bo’lgan harakatlar bor , masalan 7-harakatda Q ning maxsimum qiymatini olamiz, demak biz 7-harakatni amalga oshiramiz.

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 161350.png](attachment:0443eac6-18f1-457d-b174-8810f3c05603.png)
#
# #### Formulani  quyidagicha ham yozishimiz mumkin

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 161426.png](attachment:133c8ac4-585e-4af0-8b05-4cfec0290523.png)
#
# #### Endi biz o’zgaruvchilarni chap tarafga o’tkazib olamiz va uni 0 ga tenglashtiramiz. Bu orqali biz uni minimumga olib kelishga urinamiz.

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-03-05 161500.png](attachment:ee17cfe1-73c2-4984-a241-a4e7fb98550c.png)
#
# #### Buni bajarish uchun formulani o’rtacha kvadratik xatolikni topishga olib kelamiz

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:4920d20a-57a9-4c6a-ab7e-bdcdfe0a8324.png)
#
# #### Endi biz buni gradient descent orqali update qilishimiz kerak

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:22f93d67-1da4-48d4-8cf8-e1ce30deed3c.png)
#
# #### Tepadagi hosil bo’lgan formulamiz Q-learning formulasi deyiladi.
# #### Keling yana bir marotaba o’ylab koramiz. Biz qanday qilib optimal strategiyani tanlaymiz

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:738d720f-32cd-4228-a2ba-7519f1e24580.png)
#
# #### Bu ochko’z strategiya deyiladi nimaga ? Tasavvur qiling biz o’yin o’ynayapmiz va qaysidur momentda biz sakrashni amalga oshirdik va politikamiz tasodifdan buning uchun bizga shtraf berdi, lekin biz bu joyida shtraf olmasligimiz kerak edi, chunki bu ham to’g’ri harakat edi. Buning natijasida biz buni esalab qolamiz va keyingi safar shu holat(state) da shu harakatni bajarmaslikkga harakat qilamiz, chunki hisob kitobda argmaxQ^  (s,a) buning oldida boshqa harakatlar foydalidek ko’rinadi, lekin bu notog’ri. Shuning uchun biz har doim maxsimum qiymatni beradigan harkatlarni tanlashimiz unchalik ham to’g’ri emas, biz shu harakatlarni qandaydur ehtimollik bilan amalga oshirsak yaxshi bo’ladi.  Biz bunga qanday erishishmiz mumkin, masalan biz epsilon ehtimollik bilan harakatni amalga oshiramiz, ya’ni biz hozirgi holatimizda(state) biz qilishimiz mumkin bo’lgan random(tasodifiy) harakani amalga oshiramiz, 1-epsilon ehtimollik orqali esa biz optimal harakatni amalga oshiramiz. Biz o’rganishimizning boshida bo’lgan vaqtimizda biz Q ni bilmaymiz shuning uchun epsilon katta bo’lishi kerak. Ya’ni biz state haqida hali to’liq ma’lumorga ega emasmiz va biz o’sha stateda random harakatlarni amalga oshiramiz va bundan nima chiqishini ko’ramiz, biz shunday usul bilan tajriba yig’amiz va Q ni yanada yaxshiroq baholay oladigan bo’lamiz. Bir qancah vaqt o’tgandan keyin va biz holatlarimiz(state) haqida ko’proq malumotga ega bolganimizdan so’ng epsilonni ham kichraytiramiz, va shu orqali vaqt o’tgan sari biz random harakatlarni emas aniq bir harakatlarni amalga oshirishni boshlaymiz.
#
# #### ϵ-greedy(ϵ- ochko’z strategiya )

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:41cf02cd-cdbe-4ee7-86b4-98a2302c2404.png)
#
# #### Tepada aytib o’tganimiz Exploration-exploitation muammosi hisoblanadi, ya’ni o’rganish va tadbiq etish muammosi hisoblanadi. Biz nimadurni o’rganish qidirish jarayonida qandaydur harakatlarni amalga oshiramiz va nimadur o’rganamiz va keyinchalik shu olgan ma’lumotlarimizni ishlatamiz. Oddiyroq aytadigan bo’lsak chaqaloq ham yurishni o’rganayotgan vaqtida har hil to’gri va notog’ri harakatlarni amalga oshirib ko’radi ya’ni xato qiladi va vaqt o’tgandan keyin qanday holatda qanday yurish va nima qilishni bilganidan keyingina harakatlarini o’ylab bajarishni boshlaydi.
#
# #### Yana 1 ta misol keltirib o’taman siz o’zingiz uchun eng yaxshi kafeni topmoqchisiz. Siz 1-kafega borasiz, 2-kafega borasiz, lekin sizga u yerda yoqmaydi va siz 3-kafega kelganingizda sizga yoqadi. Bu yerda siz 1 marta kafelarga kirib chiqish orqali eng yaxshi kafeni topa olmaysiz, chunki 1-2-kafelarga kirganingizda masalan sizga kayfiyati yo’q ofitsant xizmat ko’rsatgan bo’lishi mumkin. Lekin 2-kafe boshqlardan eng yaxshisi edi.
#
# #### Bizning Q  argmax_a Q^  (s,a) har doim argmax qiymatni oladi, masalan bizda Q 99, 95, 95 va 30 bo’lishi mumkin. Agar e’tibor qaratsak 99 va 95  bir biriga yaqin lekin biz faqat 99 ni olamiz. Bu yondashuv unchalik ham to’g’ri emas, chunki 99 va 95 bir biriga yaqin. Biz 95 ga ham e’tiobor qartishimiz kerak. Biz buni to’g’irlashimiz uchun softmaxni ishlatamiz

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:64af6232-3126-4aaa-aaf5-400c2e9e2594.png)
#
# #### Ya’ni logitlarni(sonlarni) bizning Q ga proportsionlan bo’lgan ehtimolliklarga o’tkazib olamiz. Bu yerda  τ (tau)  oddiy parametr lekin biz buni ham boshida katta son olib o’qitish jarayonida kamaytirib borishimiz kerak.
# #### Tepadagi holatda biz 1 ta muammoga duch kelamiz. Bizda s va a diskter(chekli to’plam), biz masalan qandaydur continues qiymatlar bor masalan tezanish, burchak o’zgarishlari kabi, yani har doim o’zgarib turadigan. Buni to’girlash uchun biz unga θ (teta) parametrini qo’shamiz.

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:8631e268-2a20-4b8a-96a0-ccd97ff2691b.png)
#
# #### ya’ni biz θ parametr qorqali (s,a) dan Q ni olamiz

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:f1368d07-50f2-4f96-98d8-a8181d7a5797.png)
#
# #### Endi bizning vazifamiz θ (teta) parametrini o’rgatish.
# #### Bizning o’yinimiz agarda kadrlardan iborat bo’lsa birinchi bo’lib CNN qatlamidan o’tadi. Keyin ANN(Dense layer) qatlamga o’tadi.
# #### Agar o’yinimizda faqat jadval yoki faqat har xil qiymatlardan tashkil topgan bo’lsa faqat ANN(Dense layer) qatlamidan o’tadi.
# #### Pastdagi rasmga e’tibor bersangiz bizning o’yynimiz kadrlardan iborat va u
# #### 1-bo’lib CNN qatlamdan o’tadi va keyin ANN qatlamdan o’tadi

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:6c522114-f7c2-4d15-bf82-cd11df8347f0.png)
#
# #### Agarda o’yinimiz jadval yoki har xil qiymatlardan iborat bo’lsa faqat ANN(Dense layer) dan o’tadi

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:7129d18f-0449-4ecf-a1e9-7bfc7c108e90.png)

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:a5c0f47e-9e77-4269-af93-e7af49c8bd6c.png)
#
# #### Demak biz neyron to’ri bilan ishlaganimizda juda ham ko’p parametrlar bilan ishlaymiz. Agarda biz har o’yinda qaysudur joyida xato qilib halokt bo’lsak, keyingi safar uni takrorlashimiz kerak emas. Biz uni eslab qolishimiz kerak.
# #### Biz har bir iteratsiya masalan 1 ta harakatni amalga oshiramiz va  eslab qolgan harakatimizni (xotirada saqlab qolgan) ham amalga oshiramiz. Bu orqali biz o’rganishimizni tezroq amalga oshadi.
# #### Demak biz Q ni o’qitish orqali har bir state(holat) uchun eng yaxshi action(harakat) larni tanlashni o’rganamiz.

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:07750a6b-3573-4a1d-833f-915533891c5c.png)
#
# #### Neyron to’ridan chiqishda esa biz harakatlarimizni ehtimolligini olamiz(Tepadagi rasmga qarang ↑,↗,→,↘,↓,↙,←,↖, ↑●,↗●,→●,↘●,↓●,↙●,←●,↖●).
# #### Tapadagi V va Q funksiyalarini biz nimaga o’qitdik ?
# #### Politika/strategiyamizni olish uchun. Demak Q ni o’rgatish orqali biz qanday harakat qilishimizni bilib olamiz.
# #### Shu o’rinda o’rinli savol tug’iladi bizga baribir politika/strategiya kerak ekan nimaga biz Q va V funksiyani o’qityapmiz, strategiyani o’qitib qo’ysak bo’lmaydimi ?
# #### Albatta bo’ladi.

# %% [markdown]
# # <center> Policy Gradient(Reinforce)
#
# <center>
#
# #### Bizning strategiya/politikamiz bu neyron to’ri
# #### π(a,s,θ) – neyron to’ri. θ (teta) parametrlardan tashkil topgan
# #### Demak bizda s holat bor va biz uni θ parametrlaridan iborat neyron to’ridan o’tkazamiz va chiqishda har bir harakatimizning ehtimolini olamiz. Agar bizda 10 ta chiqish bo’lsa biz ularning har biri uchun 2 ta sondan hosil qilamiz. Bu 10 ta qiymat uning matematik kutilmasini va dispersyasi (μ,σ).
# #### Agar bizda Diskert harakatlar bo’lsa
# #### Neyro’n to’ridan chiqish

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:63973300-ac35-428a-8339-13744cb21cff.png)
#
# #### Biz bu yerda ham Q ni optimizatsiya qilamiz, lekin bu yerda Q ni politikadan olamiz. Endi biz politika orqali Q ni baholay olamiz.
# #### Biz bu formulada bizning hozirgi politikamizning θ parametrlari orqali Q^π (s,a) matematik kutilmasini baholayapmiz.
# #### Demak bizda π politika bor va shu politika orqali Q ni topamiz.
# #### Endi bizga tepadagi formulamizni gradienti kerak

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:0d6c713b-6aeb-4e9f-848a-69b822642c52.png)
#
# #### Tepadagi formulamiz orqali endi biz θ teta paremetrlaimizni update qilsak bo’ladi

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:3976b915-26eb-422b-8ef6-c9f1af43e080.png)
#
# #### Birinchi [] qavsning matematik kutilmasni deyarli 0 ga teng va u bizga o’yinda masalan ozgina gaz qo’sh yoki ozgina tormoz ber degan ma’noda keladi. Ikkinchi [] qavs esa Q funksiya yoki o’rtacha reward deb hisoblasak bo’adi.
# #### Agarda bizda 1-qavsdagi matematik kutilma 0.1 bo’lsa 2-qavsdagi reward 100 bo’lsa biz 10 olamiz, agarda1-qavsdagi matematik kutilma -0.1 bo’lsa va 2-qavsdagi reward 100 bo’lsa biz -10 olamiz.
# #### Biz shunda -10 dan 10 ga o’tgan bo’lamiz  u yerda dispersiya juda katta.
# #### Bu Policy gradinet usulining kamchiliklaridan biri.
#
# #### Demak biz tepada masalan, V va Q funskiyani ko’rdik`(Value-Based)`, u bizga holatimizni va harakatlarimizni foydaliligini baholash orqali ishlaydi.
# #### Policy gradient`(Policy-Based)` esa bizga politikamizni baholash orqali ishlaydi.

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:f26fc74b-d9c7-41e3-9c46-3b7d2e7f5731.png)

# %% [markdown]
# <center>
#
# # ![Screenshot 2024-02-13 114905.png](attachment:6f848a19-1bd5-46dc-92ce-f64cf48773d3.png)
#
# #### RL quyidagicha 2 bo’linar edi

# %% [markdown]
# # <center> Endi bizda `Actor-Critic` bor.

# %% [markdown]
# <center>
#
# # ![image2.png](attachment:1a0112aa-7262-410f-b34f-a4bff826739a.png)

# %% [markdown]
# <center>
#
# # ![1 _f8tDuwh5lVzHkG3l6uitQ.png](attachment:2c3218a4-d502-4a7a-a2e2-dd9c67020bba.png)
#
# #### Policy gradientda biz politikamizni o’rgatamiz ya’ni biz qilayotgan harakatlarimizni o’rgatishimiz mumkin. Q-Learningda biz harakat va holatimizni baholash orqali politikamizni o’rgatamiz.
# #### Bizda Actor-Criticda 2 ta neyron to’ri bo’ladi

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:7eaae758-ec22-4965-938e-e06666e8e16a.png)
#
# #### Biz Politikani ham Q ni ham o’qitishni bilami
# #### Politikamizni Policy Gradient orqali o’qitamiz

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:1506798a-42a3-4517-8593-9b44bf75430d.png)
#
# #### Q ni esa Q-Learning orqali o’qitamiz

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:554c2c89-1b81-45a0-9ecb-69d00e405b79.png)
#
# #### Bizda bu ikkalasini ham o’qitadigan metod `QAC(Quantile Actor-Critic)` Metod deyiladi.

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:fcac1273-ac70-4164-ae81-5861cdf73593.png)
#
# #### Bu `QAC(Quantile Actor-Critic)` metyodi edi.
# #### Bizda dispersiya xali ham, baland. Endi biz Politikamizdagi gradientning dispersiyasini kamaytirmoqchimiz

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:f161b559-0917-440e-bf40-5e9827ab35a4.png)
#
# #### Bizda ∇_θ logπ(a|s,θ_old) shu gradient deyarli 0 ga teng, Q(s,a) esa bizdan 0 dan boshqa son. Gradientimiz – yoki + va u kichkina sonligini hisobga olsak bizda dispersiyamiz baland bo’lib ketishi mumkin.
# #### Teparoqda misol keltirib o’tganimizdek gradient 0.1 yoki -0.1 bo’lsa va biz uni 100 ga kopaytirsak -10 yoki 10 olamiz va shu orqali dispersiyamiz baland bolib qoladi. Ideal holatda bizning ikkala qiymatimiz ham kichkina bolishi kerak.
# #### Shuning uchun biz Q(s,a) qiymatdan uning matematik kutilmasini ayirib tashlaymiz.

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:cdb5e227-1513-4ebc-b2bb-1aff211656f1.png)
#
# #### matematik kutilma bizda V (Foydali harakat funksiyasi – Value Funskiya)

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:1e5bdca0-ec03-4094-9a8a-e035cc20aa44.png)
#
# #### Bu holat bizda Advantage deyiladi(ya’ni afzallik yoki kuchli jixat)

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:5db7d4d1-f550-49a2-b7e4-89b2d71de132.png)
#
# #### Advanage bu bizga bizning harakatimiz o’rtacha dan yaxshi yoki yomon bo’lganini bilish uchun kerak bo’adi.(ya’ni bizning reward o’rtacha reward qiymatdan balandmi yoki pastmi shuni bilish imkonini beradi.).
# #### Biz bu orqali `A2C(Advantage Actor-Critic)` metodiga o’tishimiz mumkin bo’ladi.

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:4fff14fd-6bc0-4ab2-8279-41db03c820c8.png)

# %% [markdown]
# <center>
#
# # ![изображение.png](attachment:23638bf6-61bc-4624-a4ae-99081989af55.png)

# %% [markdown]
# # <center> <h1>    🧑‍💻  🚀
